# %% [markdown]
# <a href="https://colab.research.google.com/github/zoeebe05/3hentai-downloader-to-drive-colab/blob/main/hentaidl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar las bibliotecas necesarias
from google.colab import drive
import os
import requests
from bs4 import BeautifulSoup
import re
import zipfile
import shutil
import sys
from tqdm import tqdm
from IPython.display import clear_output  # Importar la función clear_output

# Montar Google Drive
drive.mount('/content/drive')

# Crear la carpeta CBZFILES en Drive si no existe
if not os.path.exists("/content/drive/My Drive/CBZFILES"):
    os.makedirs("/content/drive/My Drive/CBZFILES")

# Pedir al usuario que introduzca los códigos
codigos = input("Introduce los códigos separados por coma: ").split(',')

for j, codigo in enumerate(codigos):
    # Acceder a la página web
    url = f"https://es.3hentai.net/d/{codigo}"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Capturar el nombre de la página y modificarlo
    nombre_pagina = soup.title.text
    nombre_pagina = re.sub(r'[\\/*?:"<>|]', "", nombre_pagina)  # Eliminar caracteres no permitidos

    # Capturar todas las imágenes de la página
    imagenes = soup.find_all('img')
    links_imagenes = [img['src'].replace('t.jpg', '.jpg') for img in imagenes if 'src' in img.attrs]

    # Descargar las imágenes y guardarlas en un archivo CBZ
    with zipfile.ZipFile(f"{nombre_pagina} ({codigo}).cbz", 'w') as zipf:
        for i, link_imagen in enumerate(links_imagenes):
            # Limpiar la salida antes de imprimir la nueva barra de progreso
            clear_output(wait=True)
            print(f"Descargando imágenes: {i+1}/{len(links_imagenes)}", end='\r')
            imagen = requests.get(link_imagen).content
            zipf.writestr(f"{nombre_pagina}_{i}.jpg", imagen)

    # Mover el archivo CBZ a la carpeta CBZFILES en Drive
    shutil.move(f"{nombre_pagina} ({codigo}).cbz", f"/content/drive/My Drive/CBZFILES/{nombre_pagina} ({codigo}).cbz")

    print(f"\n{j+1} de {len(codigos)} archivos descargados")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Introduce los códigos separados por coma: 674051,674223,674261,673974,673809,654254,654245,673715,654253,616363,461973,468676,474370,673669,673673,673642,673650,673647,673649,673474,655388,653572,652053,641733,584291,524757,583901,508248,484011,482695,479884,432940,424262,417784,673482,673483,673485,673486,673487,630877,631744,632398,509996,502350,511091,584520405960,405960,385062,413329,673359,673310,673311,673311,673313,550534,515176,483524,438945,438945,463314,444111,436253,384900,672767,672631,672632,672477,672490,672545,672685,670647,672139,672570,672571,672621,362605,672627,669629,669550,669547
# Procesando códigos:   0%|          | 0/80 [00:00<?, ?it/s]
# Descargando imágenes:   0%|          | 0/27 [00:00<?, ?it/s]
# 1 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/42 [00:00<?, ?it/s]
# 2 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/32 [00:00<?, ?it/s]
# 3 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/31 [00:00<?, ?it/s]
# 4 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/60 [00:00<?, ?it/s]
# 5 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/35 [00:00<?, ?it/s]
# 6 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/47 [00:00<?, ?it/s]
# 7 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/31 [00:00<?, ?it/s]
# 8 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/29 [00:00<?, ?it/s]
# 9 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/62 [00:00<?, ?it/s]
# 10 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/34 [00:00<?, ?it/s]
# 11 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/32 [00:00<?, ?it/s]
# 12 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/44 [00:00<?, ?it/s]
# 13 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/22 [00:00<?, ?it/s]
# 14 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/34 [00:00<?, ?it/s]
# 15 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/62 [00:00<?, ?it/s]
# 16 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/33 [00:00<?, ?it/s]
# 17 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/19 [00:00<?, ?it/s]
# 18 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/47 [00:00<?, ?it/s]
# 19 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/29 [00:00<?, ?it/s]
# 20 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/35 [00:00<?, ?it/s]
# 21 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/29 [00:00<?, ?it/s]
# 22 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/29 [00:00<?, ?it/s]
# 23 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/38 [00:00<?, ?it/s]
# 24 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/29 [00:00<?, ?it/s]
# 25 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/29 [00:00<?, ?it/s]
# 26 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/26 [00:00<?, ?it/s]
# 27 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/29 [00:00<?, ?it/s]
# 28 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/31 [00:00<?, ?it/s]
# 29 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/28 [00:00<?, ?it/s]
# 30 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/29 [00:00<?, ?it/s]
# 31 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/28 [00:00<?, ?it/s]
# 32 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/28 [00:00<?, ?it/s]
# 33 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/28 [00:00<?, ?it/s]
# 34 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/33 [00:00<?, ?it/s]
# 35 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/33 [00:00<?, ?it/s]
# 36 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/33 [00:00<?, ?it/s]
# 37 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/34 [00:00<?, ?it/s]
# 38 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/31 [00:00<?, ?it/s]
# 39 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/37 [00:00<?, ?it/s]
# 40 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/38 [00:00<?, ?it/s]
# 41 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/39 [00:00<?, ?it/s]
# 42 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/28 [00:00<?, ?it/s]
# 43 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/26 [00:00<?, ?it/s]
# 44 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/24 [00:00<?, ?it/s]
# 45 de 80 archivos descargados
# Descargando imágenes: 0it [00:00, ?it/s]
# 46 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/32 [00:00<?, ?it/s]
# 47 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/32 [00:00<?, ?it/s]
# 48 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/29 [00:00<?, ?it/s]
# 49 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/24 [00:00<?, ?it/s]
# 50 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/22 [00:00<?, ?it/s]
# 51 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/28 [00:00<?, ?it/s]
# 52 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/28 [00:00<?, ?it/s]
# 53 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/36 [00:00<?, ?it/s]
# 54 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/26 [00:00<?, ?it/s]
# 55 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/26 [00:00<?, ?it/s]
# 56 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/24 [00:00<?, ?it/s]
# 57 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/33 [00:00<?, ?it/s]
# 58 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/33 [00:00<?, ?it/s]
# 59 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/224 [00:00<?, ?it/s]
# 60 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/33 [00:00<?, ?it/s]
# 61 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/37 [00:00<?, ?it/s]
# 62 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/29 [00:00<?, ?it/s]
# 63 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/26 [00:00<?, ?it/s]
# 64 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/39 [00:00<?, ?it/s]
# 65 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/27 [00:00<?, ?it/s]
# 66 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/22 [00:00<?, ?it/s]
# 67 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/23 [00:00<?, ?it/s]
# 68 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/32 [00:00<?, ?it/s]
# 69 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/30 [00:00<?, ?it/s]
# 70 de 80 archivos descargados
# Descargando imágenes:   0%|          | 0/35 [00:00<?, ?it/s]
